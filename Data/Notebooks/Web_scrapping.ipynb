# %%
import pandas as pd
import numpy as np
import cv2
import PIL.Image
import urllib
import os
import warnings
warnings.filterwarnings("ignore")

# %%
folder_path = '../Food-Ingredients-Recognition/Data/Data_CSV/'
folder = os.listdir(folder_path)

for x in folder:
    m = x.replace('.csv', '')
#     print(m+' = pd.read_csv("./Data/Data_CSV/'+x+'")')

# %%
lettuce = pd.read_csv("./Data/Data_CSV/lettuce.csv")
sardines = pd.read_csv("./Data/Data_CSV/sardines.csv")
cabbage = pd.read_csv("./Data/Data_CSV/cabbage.csv")
beetroot = pd.read_csv("./Data/Data_CSV/beetroot.csv")
cucumber = pd.read_csv("./Data/Data_CSV/cucumber.csv")
bacon = pd.read_csv("./Data/Data_CSV/bacon.csv")
lamb = pd.read_csv("./Data/Data_CSV/lamb.csv")
brussel_sprouts = pd.read_csv("./Data/Data_CSV/brussel_sprouts.csv")
lentils = pd.read_csv("./Data/Data_CSV/lentils.csv")
quinoa = pd.read_csv("./Data/Data_CSV/quinoa.csv")
chicken_breast = pd.read_csv("./Data/Data_CSV/chicken_breast.csv")
tortellini = pd.read_csv("./Data/Data_CSV/tortellini.csv")
broccoli = pd.read_csv("./Data/Data_CSV/broccoli.csv")
fresh_raw_beef = pd.read_csv("./Data/Data_CSV/fresh_raw_beef.csv")
chicken_whole = pd.read_csv("./Data/Data_CSV/chicken_whole.csv")
black_beans = pd.read_csv("./Data/Data_CSV/black_beans.csv")
tuna = pd.read_csv("./Data/Data_CSV/tuna.csv")
shrimps = pd.read_csv("./Data/Data_CSV/shrimps.csv")
ground_beef = pd.read_csv("./Data/Data_CSV/ground_beef.csv")
apple = pd.read_csv("./Data/Data_CSV/apple.csv")
sweet_potato = pd.read_csv("./Data/Data_CSV/sweet_potato.csv")
pork_ribs = pd.read_csv("./Data/Data_CSV/pork_ribs.csv")
fresh_pork_chop = pd.read_csv("./Data/Data_CSV/fresh_pork_chop.csv")
pasta_elbow = pd.read_csv("./Data/Data_CSV/pasta_elbow.csv")
lasagne = pd.read_csv("./Data/Data_CSV/lasagne.csv")
trout = pd.read_csv("./Data/Data_CSV/trout.csv")
red_pepper = pd.read_csv("./Data/Data_CSV/red_pepper.csv")
green_pepper = pd.read_csv("./Data/Data_CSV/green_pepper.csv")
farfalle = pd.read_csv("./Data/Data_CSV/farfalle.csv")
mussels = pd.read_csv("./Data/Data_CSV/mussels.csv")
oats = pd.read_csv("./Data/Data_CSV/oats.csv")
white_potato = pd.read_csv("./Data/Data_CSV/white_potato.csv")
chickpeas = pd.read_csv("./Data/Data_CSV/chickpeas.csv")
carrot = pd.read_csv("./Data/Data_CSV/carrot.csv")
black_eyed_peas = pd.read_csv("./Data/Data_CSV/black_eyed_peas.csv")
asparagus = pd.read_csv("./Data/Data_CSV/asparagus.csv")
tomato = pd.read_csv("./Data/Data_CSV/tomato.csv")
penne = pd.read_csv("./Data/Data_CSV/penne.csv")
aubergine = pd.read_csv("./Data/Data_CSV/aubergine.csv")
soybeans = pd.read_csv("./Data/Data_CSV/soybeans.csv")
cannelloni = pd.read_csv("./Data/Data_CSV/cannelloni.csv")
cauliflower = pd.read_csv("./Data/Data_CSV/cauliflower.csv")
spaghetti = pd.read_csv("./Data/Data_CSV/spaghetti.csv")
tagliatelle = pd.read_csv("./Data/Data_CSV/tagliatelle.csv")
zucchini = pd.read_csv("./Data/Data_CSV/zucchini.csv")
pork_belly = pd.read_csv("./Data/Data_CSV/pork_belly.csv")
onions = pd.read_csv("./Data/Data_CSV/onions.csv")
eggs_white = pd.read_csv("./Data/Data_CSV/eggs_white.csv")
butternut_squash = pd.read_csv("./Data/Data_CSV/butternut_squash.csv")
oyster = pd.read_csv("./Data/Data_CSV/oyster.csv")
wheat = pd.read_csv("./Data/Data_CSV/wheat.csv")
mushrooms = pd.read_csv("./Data/Data_CSV/mushrooms.csv")
rabbit_raw = pd.read_csv("./Data/Data_CSV/rabbit_raw.csv")
fusilli = pd.read_csv("./Data/Data_CSV/fusilli.csv")
eggs_brown = pd.read_csv("./Data/Data_CSV/eggs_brown.csv")
corn = pd.read_csv("./Data/Data_CSV/corn.csv")
mackerel = pd.read_csv("./Data/Data_CSV/mackerel.csv")
bread = pd.read_csv("./Data/Data_CSV/bread.csv")
white_rice = pd.read_csv("./Data/Data_CSV/white_rice.csv")
salmon = pd.read_csv("./Data/Data_CSV/salmon.csv")
green_mung_beans = pd.read_csv("./Data/Data_CSV/green_mung_beans.csv")
sausages = pd.read_csv("./Data/Data_CSV/sausages.csv")
red_beans = pd.read_csv("./Data/Data_CSV/red_beans.csv")

# %%
for x in folder:
    m = x.replace('.csv', '')
#     print(m+'_1 = ' + m + '["image_results.image"]')

# %%
lettuce_1 = lettuce["image_results.image"]
sardines_1 = sardines["image_results.image"]
cabbage_1 = cabbage["image_results.image"]
beetroot_1 = beetroot["image_results.image"]
cucumber_1 = cucumber["image_results.image"]
bacon_1 = bacon["image_results.image"]
lamb_1 = lamb["image_results.image"]
brussel_sprouts_1 = brussel_sprouts["image_results.image"]
lentils_1 = lentils["image_results.image"]
quinoa_1 = quinoa["image_results.image"]
chicken_breast_1 = chicken_breast["image_results.image"]
tortellini_1 = tortellini["image_results.image"]
broccoli_1 = broccoli["image_results.image"]
fresh_raw_beef_1 = fresh_raw_beef["image_results.image"]
chicken_whole_1 = chicken_whole["image_results.image"]
black_beans_1 = black_beans["image_results.image"]
tuna_1 = tuna["image_results.image"]
shrimps_1 = shrimps["image_results.image"]
ground_beef_1 = ground_beef["image_results.image"]
apple_1 = apple["image_results.image"]
sweet_potato_1 = sweet_potato["image_results.image"]
pork_ribs_1 = pork_ribs["image_results.image"]
fresh_pork_chop_1 = fresh_pork_chop["image_results.image"]
pasta_elbow_1 = pasta_elbow["image_results.image"]
lasagne_1 = lasagne["image_results.image"]
trout_1 = trout["image_results.image"]
red_pepper_1 = red_pepper["image_results.image"]
green_pepper_1 = green_pepper["image_results.image"]
farfalle_1 = farfalle["image_results.image"]
mussels_1 = mussels["image_results.image"]
oats_1 = oats["image_results.image"]
white_potato_1 = white_potato["image_results.image"]
chickpeas_1 = chickpeas["image_results.image"]
carrot_1 = carrot["image_results.image"]
black_eyed_peas_1 = black_eyed_peas["image_results.image"]
asparagus_1 = asparagus["image_results.image"]
tomato_1 = tomato["image_results.image"]
penne_1 = penne["image_results.image"]
aubergine_1 = aubergine["image_results.image"]
soybeans_1 = soybeans["image_results.image"]
cannelloni_1 = cannelloni["image_results.image"]
cauliflower_1 = cauliflower["image_results.image"]
spaghetti_1 = spaghetti["image_results.image"]
tagliatelle_1 = tagliatelle["image_results.image"]
zucchini_1 = zucchini["image_results.image"]
pork_belly_1 = pork_belly["image_results.image"]
onions_1 = onions["image_results.image"]
eggs_white_1 = eggs_white["image_results.image"]
butternut_squash_1 = butternut_squash["image_results.image"]
oyster_1 = oyster["image_results.image"]
wheat_1 = wheat["image_results.image"]
mushrooms_1 = mushrooms["image_results.image"]
rabbit_raw_1 = rabbit_raw["image_results.image"]
fusilli_1 = fusilli["image_results.image"]
eggs_brown_1 = eggs_brown["image_results.image"]
corn_1 = corn["image_results.image"]
mackerel_1 = mackerel["image_results.image"]
bread_1 = bread["image_results.image"]
white_rice_1 = white_rice["image_results.image"]
salmon_1 = salmon["image_results.image"]
green_mung_beans_1 = green_mung_beans["image_results.image"]
sausages_1 = sausages["image_results.image"]
red_beans_1 = red_beans["image_results.image"]

# %%
img_rows, img_cols = 32, 32 
input_shape = (img_rows, img_cols, 3)

def url_to_image(dw):
    resp = urllib.request.urlopen(dw)
    image = np.asarray(bytearray(resp.read()), dtype="uint8")
    image = cv2.imdecode(image, cv2.IMREAD_COLOR)
    return image
n_of_training_images=100

# %%
for progress in range(n_of_training_images):
     ingred = white_potato_1
     if not ingred[progress] == None:
      try:
        I = url_to_image(ingred[progress])
        if (len(I.shape))==3: 
          save_path = '../Food-Ingredients-Recognition/Data/ingredients/fruits_vegetables/white_potato-'+str(progress)+'.jpg'
          cv2.imwrite(save_path,I)
      except:
        None

# %%
for progress in range(n_of_training_images):
     ingred = red_beans_1
     if not ingred[progress] == None:
      try:
        I = url_to_image(ingred[progress])
        if (len(I.shape))==3: 
          save_path = '../Food-Ingredients-Recognition/Data/ingredients/grains/red_beans-'+str(progress)+'.jpg'
          cv2.imwrite(save_path,I)
      except:
        None

# %%
for progress in range(n_of_training_images):
     ingred = sausages_1
     if not ingred[progress] == None:
      try:
        I = url_to_image(ingred[progress])
        if (len(I.shape))==3: 
          save_path = '../Food-Ingredients-Recognition/Data/ingredients/meat/sausages-'+str(progress)+'.jpg'
          cv2.imwrite(save_path,I)
      except:
        None
