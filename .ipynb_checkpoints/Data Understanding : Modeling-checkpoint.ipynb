# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ##  **Data Understanding**

# %%
import split_folders

input_folder = '../Food-Ingredients-Recognition/Data/'
output_folder = '../Food-Ingredients-Recognition/Splitted_Data_Sets/'
# Split with a ratio.
# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.
split_folders.ratio(input_folder, output=output_folder, seed=1337, ratio=(.8, .1, .1)) # default values

# %%
# Importing the datasets
input_path = '../Food-Ingredients-Recognition/Splitted_Data_Sets/'
train_dir = "../Food-Ingredients-Recognition/Splitted_Data_Sets/train/"
val_dir = "../Food-Ingredients-Recognition/Splitted_Data_Sets/val/"
test_dir = "../Food-Ingredients-Recognition/Splitted_Data_Sets/test/"

# %%
# image_dataset_from_direc

# %%
import os
# Importing the training classes
apple = os.listdir(train_dir + "apple")
carrot = os.listdir(train_dir + "carrot")
pork_belly = os.listdir(train_dir + "pork_belly")
penne = os.listdir(train_dir + "penne")
chickpeas = os.listdir(train_dir + "chickpeas")
white_potato = os.listdir(train_dir + "white_potato")

# %%
# Function used to plot some training data (Normal and Pneumonia)      
import os
from skimage.transform import resize
import numpy as np

def plotter(i):
    carrot1 = cv2.imread(train_dir+"carrot/"+carrot[i])
    carrot1 = skimage.transform.resize(carrot1, (150, 150, 3))# , mode = 'reflect')
    apple1 = cv2.imread(train_dir+"apple/"+apple[i])
    apple1 = skimage.transform.resize(apple1, (150, 150, 3))
    pork_belly1 = cv2.imread(train_dir+"pork_belly/"+pork_belly[i])
    pork_belly1 = skimage.transform.resize(pork_belly1, (150, 150, 3))# , mode = 'reflect')
    penne1 = cv2.imread(train_dir+"penne/"+penne[i])
    penne1 = skimage.transform.resize(penne1, (150, 150, 3))
    chickpeas1 = cv2.imread(train_dir+"chickpeas/"+chickpeas[i])
    chickpeas1 = skimage.transform.resize(chickpeas1, (150, 150, 3))# , mode = 'reflect')
    white_potato1 = cv2.imread(train_dir+"white_potato/"+white_potato[i])
    white_potato1 = skimage.transform.resize(white_potato1, (150, 150, 3))
    pair = np.concatenate((carrot1, apple1, pork_belly1, penne1, chickpeas1, white_potato1), axis=1)

    plt.figure(figsize=(10,5))
    plt.imshow(pair)
    plt.show()
for i in range(0,5):
    plotter(i)

# %% [markdown]
# # Data Preparation

# %%
# Defining some constants
img_dims = 150
epochs = 10
batch_size = 32

# %%
from keras.preprocessing.image import ImageDataGenerator

# Function for Data generation objects
# def process_data(img_dims, batch_size):
train_datagen = ImageDataGenerator(rescale=1./255, zoom_range=0.3, vertical_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_g = train_datagen.flow_from_directory(directory=train_dir, target_size=(img_dims, img_dims), batch_size=batch_size,class_mode='categorical',shuffle=True)
val_g = val_datagen.flow_from_directory(directory=val_dir, target_size=(img_dims, img_dims), batch_size=batch_size, class_mode='categorical',shuffle=True)
test_g = test_datagen.flow_from_directory(directory=test_dir, target_size=(img_dims, img_dims), batch_size=batch_size, class_mode='categorical',shuffle=True)
# Out:
# Found 3535 images belonging to 52 classes.
# Found 419 images belonging to 52 classes.
# Found 492 images belonging to 52 classes.

# %%
train_datagen

# %% [markdown]
# # Modeling

# %%
from keras.models import Model, Sequential
from keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, SeparableConv2D, MaxPool2D, LeakyReLU, Activation

sec = Sequential()

sec.add(Conv2D(128, kernel_size=(3, 3), strides=1, activation='relu', padding='same', input_shape=(150, 150, 3)))
sec.add(MaxPool2D(pool_size=(2,2),strides=2))

sec.add(Conv2D(64, kernel_size=(3, 3), strides=1, activation='relu', padding='same'))
sec.add(MaxPool2D(pool_size=(2,2),strides=2))

sec.add(Conv2D(32, kernel_size=(3, 3), strides=1, activation='relu', padding='same'))
sec.add(MaxPool2D(pool_size=(2,2),strides=2))

sec.add(Conv2D(16, kernel_size=(3, 3), strides=1, activation='relu', padding='same'))
sec.add(MaxPool2D(pool_size=(2,2),strides=2))


sec.add(Flatten())
sec.add(Dense(8, activation='relu'))
sec.add(Dense(52, activation='softmax'))

sec.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
sec.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_13 (Conv2D)           (None, 150, 150, 128)     3584
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 75, 75, 128)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 75, 75, 64)        73792
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 37, 37, 32)        18464
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 18, 18, 32)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 18, 18, 16)        4624
# ...

# %%
# Fit_generator function
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

hist_s = sec.fit_generator(generator=train_g, steps_per_epoch=50, epochs=20, validation_data=val_g, validation_steps=val_g.samples // batch_size)#, callbacks=[checkpoint, lr_reduce])
# Out:
# Epoch 1/20
# 50/50 [==============================] - 148s 3s/step - loss: 3.9495 - accuracy: 0.0162 - val_loss: 3.9531 - val_accuracy: 0.0192
# Epoch 2/20
# 50/50 [==============================] - 152s 3s/step - loss: 3.9477 - accuracy: 0.0215 - val_loss: 3.9544 - val_accuracy: 0.0362
# Epoch 3/20
# 50/50 [==============================] - 161s 3s/step - loss: 3.9464 - accuracy: 0.0177 - val_loss: 3.9678 - val_accuracy: 0.0129
# Epoch 4/20
# 50/50 [==============================] - 197s 4s/step - loss: 3.9466 - accuracy: 0.0188 - val_loss: 3.9418 - val_accuracy: 0.0052
# Epoch 5/20
# 50/50 [==============================] - 166s 3s/step - loss: 3.9363 - accuracy: 0.0169 - val_loss: 3.9040 - val_accuracy: 0.0233
# Epoch 6/20
# 50/50 [==============================] - 140s 3s/step - loss: 3.8961 - accuracy: 0.0259 - val_loss: 3.9331 - val_accuracy: 0.0284
# Epoch 7/20
# ...

# %%
# PLotting the model's output
import matplotlib.pyplot as plt 
acc = hist_s.history['accuracy']
val_acc = hist_s.history['val_accuracy']
loss = hist_s.history['loss']
val_loss = hist_s.history['val_loss']
epochs = range(len(acc))
plt.plot(epochs, acc, 'teal', label='Train acc')
plt.plot(epochs, val_acc, 'firebrick', label='Val acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'teal', label='Train loss')
plt.plot(epochs, val_loss, 'firebrick', label='Val loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# # model 2

# %%
from keras.models import Model, Sequential
from keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, SeparableConv2D, MaxPool2D, LeakyReLU, Activation

sec2 = Sequential()

sec2.add(Conv2D(256, kernel_size=(3, 3), strides=1, activation='relu', padding='same', input_shape=(150, 150, 3)))
sec2.add(MaxPool2D(pool_size=(2,2),strides=2))

sec2.add(Conv2D(128, kernel_size=(3, 3), strides=1, activation='relu', padding='same', input_shape=(150, 150, 3)))
sec2.add(MaxPool2D(pool_size=(2,2),strides=2))

sec2.add(Conv2D(64, kernel_size=(3, 3), strides=1, activation='relu', padding='same'))
sec2.add(MaxPool2D(pool_size=(2,2),strides=2))

sec2.add(Conv2D(32, kernel_size=(3, 3), strides=1, activation='relu', padding='same'))
sec2.add(MaxPool2D(pool_size=(2,2),strides=2))

sec2.add(Conv2D(16, kernel_size=(3, 3), strides=1, activation='relu', padding='same'))
sec2.add(MaxPool2D(pool_size=(2,2),strides=2))


sec2.add(Flatten())
sec2.add(Dense(8, activation='relu'))
sec2.add(Dense(52, activation='softmax'))

sec2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
sec2.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_17 (Conv2D)           (None, 150, 150, 256)     7168
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 75, 75, 256)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 75, 75, 128)       295040
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 37, 37, 64)        73792
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 18, 18, 64)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 18, 18, 32)        18464
# ...

# %%
# Fit_generator function
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

hist_2 = sec2.fit_generator(generator=train_g, steps_per_epoch=10, epochs=50, validation_data=val_g, validation_steps=val_g.samples // batch_size)#, callbacks=[checkpoint, lr_reduce])
# Out:
# Epoch 1/50
# 10/10 [==============================] - 76s 8s/step - loss: 3.3098 - accuracy: 0.0875 - val_loss: 3.1660 - val_accuracy: 0.1106
# Epoch 2/50
# 10/10 [==============================] - 72s 7s/step - loss: 3.2567 - accuracy: 0.1250 - val_loss: 3.0781 - val_accuracy: 0.1059
# Epoch 3/50
# 10/10 [==============================] - 72s 7s/step - loss: 3.2755 - accuracy: 0.1063 - val_loss: 3.1491 - val_accuracy: 0.1059
# Epoch 4/50
# 10/10 [==============================] - 73s 7s/step - loss: 3.2044 - accuracy: 0.0812 - val_loss: 3.1703 - val_accuracy: 0.1214
# Epoch 5/50
# 10/10 [==============================] - 72s 7s/step - loss: 3.2415 - accuracy: 0.0938 - val_loss: 3.2899 - val_accuracy: 0.1059
# Epoch 6/50
# 10/10 [==============================] - 72s 7s/step - loss: 3.1499 - accuracy: 0.0906 - val_loss: 3.0194 - val_accuracy: 0.1111
# Epoch 7/50
# ...

# %%
import matplotlib.pyplot as plt 
acc = hist_s.history['accuracy']
val_acc = hist_s.history['val_accuracy']
loss = hist_s.history['loss']
val_loss = hist_s.history['val_loss']
epochs = range(len(acc))
plt.plot(epochs, acc, 'teal', label='Train acc')
plt.plot(epochs, val_acc, 'firebrick', label='Val acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'teal', label='Train loss')
plt.plot(epochs, val_loss, 'firebrick', label='Val loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ###  model 3

# %%
from keras.models import Model, Sequential
from keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, SeparableConv2D, MaxPool2D, LeakyReLU, Activation

sec_3 = Sequential()

sec_3.add(Conv2D(256, kernel_size=(3, 3), strides=1, activation='relu', padding='same', input_shape=(150, 150, 3)))
sec_3.add(MaxPool2D(pool_size=(2,2),strides=2))

sec_3.add(Conv2D(128, kernel_size=(3, 3), strides=1, activation='relu', padding='same'))
sec_3.add(MaxPool2D(pool_size=(2,2),strides=2))

sec_3.add(Conv2D(64, kernel_size=(3, 3), strides=1, activation='relu', padding='same'))
sec_3.add(MaxPool2D(pool_size=(2,2),strides=2))

sec_3.add(Conv2D(32, kernel_size=(3, 3), strides=1, activation='relu', padding='same'))
sec_3.add(MaxPool2D(pool_size=(2,2),strides=2))


sec_3.add(Flatten())
sec_3.add(Dense(8, activation='relu'))
sec_3.add(Dense(52, activation='softmax'))

sec_3.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
sec_3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_5 (Conv2D)            (None, 150, 150, 256)     7168
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 75, 75, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 75, 75, 128)       295040
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 37, 37, 64)        73792
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 18, 18, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 18, 18, 32)        18464
# ...

# %%
# Fit_generator function
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

hist_3 = sec_3.fit_generator(generator=train_g, steps_per_epoch=10, epochs=50, validation_data=val_g, validation_steps=val_g.samples // batch_size)#, callbacks=[checkpoint, lr_reduce])
# Out:
# Epoch 1/50
# 10/10 [==============================] - 94s 9s/step - loss: 3.9536 - accuracy: 0.0312 - val_loss: 3.9505 - val_accuracy: 0.0216
# Epoch 2/50
# 10/10 [==============================] - 88s 9s/step - loss: 3.9508 - accuracy: 0.0132 - val_loss: 3.9502 - val_accuracy: 0.0207
# Epoch 3/50
# 10/10 [==============================] - 89s 9s/step - loss: 3.9511 - accuracy: 0.0250 - val_loss: 3.9482 - val_accuracy: 0.0181
# Epoch 4/50
# 10/10 [==============================] - 87s 9s/step - loss: 3.9505 - accuracy: 0.0312 - val_loss: 3.9502 - val_accuracy: 0.0258
# Epoch 5/50
# 10/10 [==============================] - 85s 9s/step - loss: 3.9503 - accuracy: 0.0281 - val_loss: 3.9510 - val_accuracy: 0.0233
# Epoch 6/50
# 10/10 [==============================] - 84s 8s/step - loss: 3.9509 - accuracy: 0.0250 - val_loss: 3.9484 - val_accuracy: 0.0233
# Epoch 7/50
# ...

# %%
import matplotlib.pyplot as plt 
acc = hist_3.history['accuracy']
val_acc = hist_3.history['val_accuracy']
loss = hist_3.history['loss']
val_loss = hist_3.history['val_loss']
epochs = range(len(acc))
plt.plot(epochs, acc, 'teal', label='Train acc')
plt.plot(epochs, val_acc, 'firebrick', label='Val acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'teal', label='Train loss')
plt.plot(epochs, val_loss, 'firebrick', label='Val loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# # model 4

# %%
from keras.models import Model, Sequential
from keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, SeparableConv2D, MaxPool2D, LeakyReLU, Activation

sec4 = Sequential()

sec4.add(Conv2D(128, kernel_size=(3, 3), strides=1, activation='relu', padding='same', input_shape=(150, 150, 3)))
sec4.add(MaxPool2D(pool_size=(2,2),strides=2))

sec4.add(Conv2D(64, kernel_size=(3, 3), strides=1, activation='relu', padding='same'))
sec4.add(MaxPool2D(pool_size=(2,2),strides=2))

sec4.add(Conv2D(32, kernel_size=(3, 3), strides=1, activation='relu', padding='same'))
sec4.add(MaxPool2D(pool_size=(2,2),strides=2))

sec4.add(Conv2D(16, kernel_size=(3, 3), strides=1, activation='relu', padding='same'))
sec4.add(MaxPool2D(pool_size=(2,2),strides=2))


sec4.add(Flatten())
sec4.add(Dense(8, activation='relu'))
sec4.add(Dense(52, activation='softmax'))

sec4.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
sec4.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 150, 150, 128)     3584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 75, 75, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 64)        73792
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 37, 37, 32)        18464
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 18, 18, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 18, 18, 16)        4624
# ...

# %%
# Fit_generator function
# changed the number of epochs from 20 to 50
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

hist_4= sec4.fit_generator(generator=train_g, steps_per_epoch=50, epochs=50, validation_data=val_g, validation_steps=val_g.samples // batch_size)#, callbacks=[checkpoint, lr_reduce])
# Out:
# Epoch 1/50
# 50/50 [==============================] - 158s 3s/step - loss: 3.2488 - accuracy: 0.0856 - val_loss: 3.1433 - val_accuracy: 0.1058
# Epoch 2/50
# 50/50 [==============================] - 149s 3s/step - loss: 3.2937 - accuracy: 0.0878 - val_loss: 3.0787 - val_accuracy: 0.1059
# Epoch 3/50
# 50/50 [==============================] - 159s 3s/step - loss: 3.1595 - accuracy: 0.0988 - val_loss: 3.0622 - val_accuracy: 0.1085
# Epoch 4/50
# 50/50 [==============================] - 159s 3s/step - loss: 3.1830 - accuracy: 0.1099 - val_loss: 3.1579 - val_accuracy: 0.1034
# Epoch 5/50
# 50/50 [==============================] - 160s 3s/step - loss: 3.1278 - accuracy: 0.1094 - val_loss: 3.1241 - val_accuracy: 0.1292
# Epoch 6/50
# 50/50 [==============================] - 183s 4s/step - loss: 3.0977 - accuracy: 0.1263 - val_loss: 3.0407 - val_accuracy: 0.1214
# Epoch 7/50
# ...

# %%
import matplotlib.pyplot as plt 
acc = hist_4.history['accuracy']
val_acc = hist_4.history['val_accuracy']
loss = hist_4.history['loss']
val_loss = hist_4.history['val_loss']
epochs = range(len(acc))
plt.plot(epochs, acc, 'teal', label='Train acc')
plt.plot(epochs, val_acc, 'firebrick', label='Val acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'teal', label='Train loss')
plt.plot(epochs, val_loss, 'firebrick', label='Val loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# # model 5

# %%
# Fit_generator function
# changed the number of epochs from 50 to 150
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

hist_5= sec4.fit_generator(generator=train_g, steps_per_epoch=50, epochs=150, validation_data=val_g, validation_steps=val_g.samples // batch_size)#, callbacks=[checkpoint, lr_reduce])
# Out:
# Epoch 1/150
# 50/50 [==============================] - 163s 3s/step - loss: 3.9484 - accuracy: 0.0310 - val_loss: 3.9218 - val_accuracy: 0.0433
# Epoch 2/150
# 50/50 [==============================] - 161s 3s/step - loss: 3.9210 - accuracy: 0.0331 - val_loss: 3.8574 - val_accuracy: 0.0388
# Epoch 3/150
# 50/50 [==============================] - 150s 3s/step - loss: 3.8379 - accuracy: 0.0385 - val_loss: 3.8922 - val_accuracy: 0.0284
# Epoch 4/150
# 50/50 [==============================] - 150s 3s/step - loss: 3.7828 - accuracy: 0.0487 - val_loss: 3.6252 - val_accuracy: 0.0543
# Epoch 5/150
# 50/50 [==============================] - 146s 3s/step - loss: 3.6925 - accuracy: 0.0631 - val_loss: 3.8166 - val_accuracy: 0.0362
# Epoch 6/150
# 50/50 [==============================] - 149s 3s/step - loss: 3.6373 - accuracy: 0.0481 - val_loss: 3.6039 - val_accuracy: 0.0879
# Epoch 7/150
# ...

# %%
import matplotlib.pyplot as plt 
acc = hist_5.history['accuracy']
val_acc = hist_5.history['val_accuracy']
loss = hist_5.history['loss']
val_loss = hist_5.history['val_loss']
epochs = range(len(acc))
plt.plot(epochs, acc, 'teal', label='Train acc')
plt.plot(epochs, val_acc, 'firebrick', label='Val acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'teal', label='Train loss')
plt.plot(epochs, val_loss, 'firebrick', label='Val loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()
